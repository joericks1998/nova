# %%
from nova_py import nova
import tensorflow as tf

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

text = "Transformers are amazing! DaVinci"
tokens = tokenizer.tokenize(text)
ids = tokenizer.convert_tokens_to_ids(tokens)

print("Tokens:", tokens)
print("Token IDs:", ids)
# Out:
# Tokens: ['transformers', 'are', 'amazing', '!', 'da', '##vin', '##ci']
# Token IDs: [19081, 2024, 6429, 999, 4830, 6371, 6895]

# %%
tf.constant(ids).shape[0]
# Out:
# 7

# %%
feature_struct = [10000]

model = nova.Model(feature_struct = feature_struct)

# %%
model.vocabulary.performer
# Out:
# {'in_tokens': {},
#  'out_tokens': {0: '#PAD',
#   1: '#STOP',
#   2: '#MEM',
#   3: "'",
#   4: '"',
#   5: 'Module',
#   6: '(',
#   7: 'body',
#   8: '=',
#   9: '[',
#   10: 'ImportFrom',
#   11: 'module',
#   12: ',',
#   13: ' ',
#   14: 'names',
#   15: 'alias',
#   16: 'name',
#   17: ')',
#   18: ']',
#   19: 'level',
#   20: 'Import',
#   21: 'ClassDef',
#   22: 'bases',
#   23: 'Name',
#   24: 'id',
#   25: 'ctx',
#   26: 'Load',
#   27: 'keywords',
#   28: 'FunctionDef',
#   29: 'args',
#   30: 'arguments',
#   31: 'posonlyargs',
#   32: 'arg',
#   33: 'kwonlyargs',
#   34: 'kw_defaults',
#   35: 'defaults',
#   36: 'Expr',
#   37: 'value',
#   38: 'Call',
#   39: 'func',
#   40: 'Attribute',
#   41: 'Constant',
#   42: 'attr',
#   43: 'decorator_list',
#   44: 'While',
#   45: 'test',
#   46: 'True',
#   47: 'kind',
#   48: 'b',
#   49: 'keyword',
#   50: 'YieldFrom',
#   51: 'orelse',
#   52: 'If',
#   53: 'Compare',
#   54: 'left',
#   55: 'ops',
#   56: 'Eq',
# ...

# %%
test = ['the world is an oyster', 'check']

# %%
model.handle(test, token_limit=100)
# Out:
# tokenizing...
# passing forward...
# /usr/local/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ['#MEMeltsnamesnamesbodyecomparatorsAddCallFloorDivImportFrom"\'bName",moduleattrClassDefoptional_vars,asnameopRaiseWhileExceptHandlerTupleLtEAsyncFunctionDef== -]argsLShiftLShiftbodyBinOp)basesbasesnameAssertmodule]basesWithExpr"CallNamegeneratorscausebodyupperFalse("varargGlobalargsTrueorelseidIfExp.argumentsSetvaluemoduleStore =levelCallFalseClassDefModattrImportFrom -idcomparatorsargstype"moduleTrue =testNotEq]\'ConstantaliasLtE',
# ...

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# %%
python_string = """
good_morning = "Vietnam!"
"""

nova.prepPythonDataset([python_string], model=model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       1 python_string = """
#       2 good_morning = "Vietnam!"
#       3 """
# ----> 5 nova.prepPythonDataset([python_string], model=model)
#
# AttributeError: module 'nova_py.nova' has no attribute 'prepPythonDataset'

# %%
model.fit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.fit()
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /usr/local/lib/python3.11/site-packages/keras/src/trainers/data_adapters/data_adapter_utils.py:104, in <genexpr>(.0)
#     103 def check_data_cardinality(data):
# --> 104     num_samples = set(int(i.shape[0]) for i in tree.flatten(data))
#     105     if len(num_samples) > 1:
#     106         msg = (
# ...

# %%
model.vocabulary.performer["out_tokens"]
# Out:
# {0: '#PAD',
#  1: '#STOP',
#  2: '#MEM',
#  3: "'",
#  4: '"',
#  5: 'Module',
#  6: '(',
#  7: 'body',
#  8: '=',
#  9: '[',
#  10: 'ImportFrom',
#  11: 'module',
#  12: ',',
#  13: ' ',
#  14: 'names',
#  15: 'alias',
#  16: 'name',
#  17: ')',
#  18: ']',
#  19: 'level',
#  20: 'Import',
#  21: 'ClassDef',
#  22: 'bases',
#  23: 'Name',
#  24: 'id',
#  25: 'ctx',
#  26: 'Load',
#  27: 'keywords',
#  28: 'FunctionDef',
#  29: 'args',
#  30: 'arguments',
#  31: 'posonlyargs',
#  32: 'arg',
#  33: 'kwonlyargs',
#  34: 'kw_defaults',
#  35: 'defaults',
#  36: 'Expr',
#  37: 'value',
#  38: 'Call',
#  39: 'func',
#  40: 'Attribute',
#  41: 'Constant',
#  42: 'attr',
#  43: 'decorator_list',
#  44: 'While',
#  45: 'test',
#  46: 'True',
#  47: 'kind',
#  48: 'b',
#  49: 'keyword',
#  50: 'YieldFrom',
#  51: 'orelse',
#  52: 'If',
#  53: 'Compare',
#  54: 'left',
#  55: 'ops',
#  56: 'Eq',
#  57: 'comparators',
#  58: 'Assign',
#  59: 'targets',
#  60: 'Store',
#  61: 'False',
# ...
