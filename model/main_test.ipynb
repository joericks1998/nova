# %%
from core import nova, embedding
import importlib
import torch
import spacy

importlib.reload(embedding)
# Out:
# <module 'core.embedding' from '/Users/joericks/Desktop/nova/model/core/embedding.py'>

# %%
# test embedding first

example = ['jims','dog','went', 'to', 'the', 'park']

e = embedding.Embed(example)

vec = e.Vector

tokens = e.tokens

vec
# Out:
# array([ 1.29661013e-04, -3.25907022e-04,  7.32354019e-05,  1.54411377e-04,
#         2.95321457e-04, -3.50266375e-04, -7.20103271e-05,  4.30162996e-04,
#        -1.65243706e-04,  4.84025404e-05, -4.62655844e-05, -3.84284795e-04,
#        -5.27947152e-04, -1.26661311e-04, -1.80938820e-04, -8.61819601e-04,
#        -1.94376102e-04,  9.01279971e-04, -4.25258768e-04, -1.31929250e-04,
#         5.65930794e-04, -3.50526330e-04,  5.81521890e-04,  6.21381798e-04,
#        -1.71509106e-04,  2.94476445e-06,  1.49871761e-04,  5.65724622e-04,
#         5.16511100e-05, -2.48468976e-04, -8.18185799e-04,  9.64952633e-05,
#         3.11696465e-04, -2.89858057e-04, -2.23178649e-04, -1.42635850e-04,
#        -4.05919243e-04,  9.28822337e-05,  3.22104897e-04,  3.63393156e-05,
#        -7.41172524e-04,  6.93562441e-04, -1.37040426e-03, -1.46368679e-04,
#         3.86766740e-04,  2.08832407e-05,  5.18607740e-05,  3.75962583e-04,
# ...

# %%
model = nova.Nova(input_dim=512, output_dim=128, nhead=8, num_encoder_layers=6, num_decoder_layers=6)

src_seq = torch.rand((10, 32, 512))  # (sequence length, batch size, input_dim)
tgt_seq = torch.rand((20, 32, 512))  # (sequence length, batch size, input_dim)

# Forward pass
output = model.forward(src_seq, tgt_seq)
# Out:
# /usr/local/lib/python3.9/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
# build vocabulary from spacy

nlp = spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 3
#       1 # build vocabulary from spacy
# ----> 3 nlp = spacy.load('en_core_web_sm')
#
# File /usr/local/lib/python3.9/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
# ...
